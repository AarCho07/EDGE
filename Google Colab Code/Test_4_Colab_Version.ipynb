# %% [markdown]
# <a href="https://colab.research.google.com/github/AarCho07/EDGE/blob/main/Test_4_Colab_Version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install gridstatus pandas
# Out:
# Collecting gridstatus
#   Downloading gridstatus-0.36.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: beautifulsoup4~=4.13 in /opt/anaconda3/lib/python3.13/site-packages (from gridstatus) (4.13.5)
# Collecting certifi~=2025.1 (from gridstatus)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting cryptography<47,>=46.0.6 (from gridstatus)
#   Downloading cryptography-46.0.7-cp311-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Collecting filelock<4,>=3.20.3 (from gridstatus)
#   Downloading filelock-3.29.7-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: frozendict~=2.4 in /opt/anaconda3/lib/python3.13/site-packages (from gridstatus) (2.4.6)
# Requirement already satisfied: h11<1,>=0.16.0 in /opt/anaconda3/lib/python3.13/site-packages (from gridstatus) (0.16.0)
# Requirement already satisfied: lxml~=5.3 in /opt/anaconda3/lib/python3.13/site-packages (from gridstatus) (5.3.0)
# Requirement already satisfied: openpyxl~=3.1 in /opt/anaconda3/lib/python3.13/site-packages (from gridstatus) (3.1.5)
# Collecting pdfplumber~=0.11 (from gridstatus)
#   Downloading pdfplumber-0.11.10-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: plotly~=6.0 in /opt/anaconda3/lib/python3.13/site-packages (from gridstatus) (6.3.0)
# Collecting requests<3,>=2.33 (from gridstatus)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting setuptools<79,>=78.1.1 (from gridstatus)
#   Downloading setuptools-78.1.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: tabulate~=0.9 in /opt/anaconda3/lib/python3.13/site-packages (from gridstatus) (0.9.0)
# Collecting termcolor~=3.0 (from gridstatus)
#   Downloading termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: tqdm~=4.67 in /opt/anaconda3/lib/python3.13/site-packages (from gridstatus) (4.67.1)
# Collecting urllib3<3,>=2.6.3 (from gridstatus)
#   Downloading urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting virtualenv<21,>=20.36.1 (from gridstatus)
#   Downloading virtualenv-20.39.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting xlrd~=2.0 (from gridstatus)
#   Downloading xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting xmltodict~=0.14 (from gridstatus)
#   Downloading xmltodict-0.15.1-py2.py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: zipp~=3.21 in /opt/anaconda3/lib/python3.13/site-packages (from gridstatus) (3.23.0)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.13/site-packages (from beautifulsoup4~=4.13->gridstatus) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from beautifulsoup4~=4.13->gridstatus) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from cryptography<47,>=46.0.6->gridstatus) (2.0.0)
# Requirement already satisfied: et_xmlfile in /opt/anaconda3/lib/python3.13/site-packages (from openpyxl~=3.1->gridstatus) (2.0.0)
# Collecting pdfminer.six==20260107 (from pdfplumber~=0.11->gridstatus)
#   Downloading pdfminer_six-20260107-py3-none-any.whl.metadata (4.3 kB)
# Collecting Pillow>=12.2.0 (from pdfplumber~=0.11->gridstatus)
#   Downloading pillow-12.3.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting pypdfium2>=5.9.0 (from pdfplumber~=0.11->gridstatus)
#   Downloading pypdfium2-5.11.0-py3-none-macosx_12_0_arm64.whl.metadata (71 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from pdfminer.six==20260107->pdfplumber~=0.11->gridstatus) (3.4.4)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/anaconda3/lib/python3.13/site-packages (from plotly~=6.0->gridstatus) (2.7.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from plotly~=6.0->gridstatus) (25.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.33->gridstatus) (3.11)
# Collecting distlib<1,>=0.3.7 (from virtualenv<21,>=20.36.1->gridstatus)
#   Downloading distlib-0.4.3-py2.py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /opt/anaconda3/lib/python3.13/site-packages (from virtualenv<21,>=20.36.1->gridstatus) (4.5.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography<47,>=46.0.6->gridstatus) (2.23)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading gridstatus-0.36.0-py3-none-any.whl (551 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 551.2/551.2 kB 9.0 MB/s  0:00:00
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading cryptography-46.0.7-cp311-abi3-macosx_10_9_universal2.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 12.4 MB/s  0:00:00 eta 0:00:01
# Downloading filelock-3.29.7-py3-none-any.whl (46 kB)
# Downloading pdfplumber-0.11.10-py3-none-any.whl (60 kB)
# Downloading pdfminer_six-20260107-py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 14.9 MB/s  0:00:00 eta 0:00:01
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
# Downloading setuptools-78.1.1-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 13.5 MB/s  0:00:00
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
# Downloading virtualenv-20.39.1-py3-none-any.whl (5.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 17.2 MB/s  0:00:00 eta 0:00:01
# Downloading distlib-0.4.3-py2.py3-none-any.whl (470 kB)
# Downloading xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# Downloading xmltodict-0.15.1-py2.py3-none-any.whl (11 kB)
# Downloading pillow-12.3.0-cp313-cp313-macosx_11_0_arm64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 16.7 MB/s  0:00:00 eta 0:00:01
# Downloading pypdfium2-5.11.0-py3-none-macosx_12_0_arm64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 17.8 MB/s  0:00:00
# Installing collected packages: distlib, xmltodict, xlrd, urllib3, termcolor, setuptools, pypdfium2, Pillow, filelock, certifi, virtualenv, requests, cryptography, pdfminer.six, pdfplumber, gridstatus
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 80.9.0
#     Uninstalling setuptools-80.9.0:
#       Successfully uninstalled setuptools-80.9.0━━━━━━━━━━━━━━━━━━  5/16 [setuptools]
#   Attempting uninstall: Pillow0m╺━━━━━━━━━━━━━━━━━━━━━━━━  6/16 [pypdfium2]]
#     Found existing installation: pillow 12.0.0━━━━━━━━━━━━━━━━  6/16 [pypdfium2]
#     Uninstalling pillow-12.0.0:0m━━━━━━━━━━━━━━━━━━━━━━━━  6/16 [pypdfium2]
#       Successfully uninstalled pillow-12.0.0━━━━━━━━━━━━━━━━━━  6/16 [pypdfium2]
#   Attempting uninstall: filelock1m╸━━━━━━━━━━━━━━━━━━━━━━  7/16 [Pillow]
#     Found existing installation: filelock 3.20.0━━━━━━━━━━━━━━  7/16 [Pillow]
#     Uninstalling filelock-3.20.0:0m━━━━━━━━━━━━━━━━━━━━━━  7/16 [Pillow]
#       Successfully uninstalled filelock-3.20.0━━━━━━━━━━━━━━━━  7/16 [Pillow]
#   Attempting uninstall: certifi━━━━━━━━━━━━━━━━━━━━━━  7/16 [Pillow]
#     Found existing installation: certifi 2026.6.17━━━━━━━━━━━━  7/16 [Pillow]
#     Uninstalling certifi-2026.6.17:━━━━━━━━━━━━━━━━━━━━━━  7/16 [Pillow]
#       Successfully uninstalled certifi-2026.6.17━━━━━━━━━━━━━━  7/16 [Pillow]
#   Attempting uninstall: requests━━━━━━━━━━━━━━━━━━━━━━  7/16 [Pillow]
#     Found existing installation: requests 2.32.5m━━━━━━━━━━━━ 11/16 [requests]
#     Uninstalling requests-2.32.5:0m╸━━━━━━━━━━━━ 11/16 [requests]
#       Successfully uninstalled requests-2.32.5━━━━━━━━━━━━ 11/16 [requests]
#   Attempting uninstall: cryptography╸━━━━━━━━━━━━ 11/16 [requests]
#     Found existing installation: cryptography 46.0.3━━━━━━━━━━ 11/16 [requests]
#     Uninstalling cryptography-46.0.3:91m╸━━━━━━━━━━━━ 11/16 [requests]
#       Successfully uninstalled cryptography-46.0.3━━━━━━━━━━━━ 11/16 [requests]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [gridstatus]6 [gridstatus]x]
# Successfully installed Pillow-12.3.0 certifi-2025.11.12 cryptography-46.0.7 distlib-0.4.3 filelock-3.29.7 gridstatus-0.36.0 pdfminer.six-20260107 pdfplumber-0.11.10 pypdfium2-5.11.0 requests-2.34.2 setuptools-78.1.1 termcolor-3.3.0 urllib3-2.7.0 virtualenv-20.39.1 xlrd-2.0.2 xmltodict-0.15.1
# Note: you may need to restart the kernel to use updated packages.

# %%
"""
ISO-NE & NYISO Preliminary Real-Time Five-Minute LMP Downloader
----------------------------------------------------------------
Uses the open-source `gridstatus` library to pull ISO-NE and NYISO
5-minute LMP data automatically every 2 minutes. No account required.

Install dependencies:
    pip install gridstatus pandas

Usage:
    python isone_download_5min_lmp.py

Output:
    - Timestamped CSVs saved to ./downloads/
    - Master files: isone_5min_lmp_MASTER.csv, nyiso_5min_lmp_MASTER.csv

Location options (edit LOCATIONS below):
    "ALL"                  → every hub, zone, and interface
    ["H.INTERNAL_HUB"]    → ISO-NE Hub only
    [".Z.MAINE", ".Z.CONNECTICUT", ...]  → specific load zones

All available ISO-NE zones:
    .Z.MAINE, .Z.NEWHAMPSHIRE, .Z.VERMONT, .Z.CONNECTICUT,
    .Z.RHODEISLAND, .Z.SEMASS, .Z.WCMASS, .Z.NEMASSBOST
"""

import os
import sys
import time
import gridstatus
from datetime import datetime
from collections import deque
#When it's full and you add a new item, it automatically drops the oldest one.
#Used to track the last 5 downloaded file paths — so the list never grows beyond 5 no matter how long the script runs.

import pandas as pd

# ── Config ────────────────────────────────────────────────────────────────────

LOCATIONS       = "ALL"        # variable that tells gridstatus that we want to download data for everysingle pricing node, hub, and zone available.
OUTPUT_DIR      = "downloads_ISO"  # Defines the name of the folder where the files will go to
ISONE_MASTER    = os.path.join(OUTPUT_DIR, "isone_5min_lmp_MASTER.csv")
NYISO_MASTER    = os.path.join(OUTPUT_DIR, "nyiso_5min_lmp_MASTER.csv")
POLL_INTERVAL   = 120          # seconds between each fetch attempt (2 minutes)
RECENT_FILES_N  = 5            # how many recent downloaded files to display


# ── Master file helpers ───────────────────────────────────────────────────────

def append_to_master(df, master_path: str, time_col: str = "Time"): #

    #Append new rows to the master CSV. Dedupes on (Time + Location) so that running during the same 5-minute interval never adds duplicate rows. Returns: (min_time, max_time, total_row_count, was_duplicate)

    os.makedirs(OUTPUT_DIR, exist_ok=True) #Checks computer storage. If folder does not exist yet, it will create it. If it does exist, it ensures the code keeps running without crashing

    if os.path.exists(master_path): #looks to see if a masterfile has already been created from a prior run
        existing = pd.read_csv(master_path) #i
        # CRITICAL: parse Time immediately so it's a Timestamp, not a string.
        # Without this, drop_duplicates sees str != Timestamp and misses dupes.
        if time_col in existing.columns:
            existing[time_col] = pd.to_datetime(existing[time_col], utc=True)
        rows_before = len(existing) #counts and saves how many rows are in the master file before adding anything. Compares this to the count after adding, to detect whether new data was actually added or if it was all duplicates.
        combined = pd.concat([existing, df], ignore_index=True) # Glues the old historical data table and the brand-new downloaded data table together, creating one giant stacked table called combined
    else:
        rows_before = 0
        combined = df.copy()

    # Dedupe on Time + Location (same interval pulled twice = no new rows)
    dedupe_cols = [c for c in [time_col, "Location"] if c in combined.columns]
    if dedupe_cols:
        combined = combined.drop_duplicates(subset=dedupe_cols, keep="last")

    # Sort chronologically and convert timestamps one more time to be safe (in case anything slipped through
    if time_col in combined.columns:
        combined[time_col] = pd.to_datetime(combined[time_col], utc=True)
        combined = combined.sort_values(time_col)

    combined.to_csv(master_path, index=False)

    rows_after = len(combined)
    was_duplicate = (rows_after == rows_before)

    if time_col in combined.columns and len(combined) > 0:
        return combined[time_col].min(), combined[time_col].max(), rows_after, was_duplicate
    return None, None, rows_after, was_duplicate


def count_intervals(master_path: str, time_col: str = "Time") -> int:
    """Count how many distinct 5-minute snapshots are in a master file."""
    if not os.path.exists(master_path):
        return 0
    existing = pd.read_csv(master_path)
    if time_col not in existing.columns:
        return 0
    return existing[time_col].nunique()


# ── Downloaders ───────────────────────────────────────────────────────────────

def download_lmp():
    """Fetch latest ISO-NE RT 5-Min LMPs, save snapshot, append to master."""
    iso = gridstatus.ISONE()

    print("----------- NE ISO ----------")
    print("Fetching latest ISO-NE Preliminary Real-Time 5-Minute LMPs...")
    df = iso.get_lmp(date="latest", market="REAL_TIME_5_MIN", locations=LOCATIONS)

    if df is None or df.empty:
        raise ValueError("No data returned. The market may not be active right now / Check Connection.")

    os.makedirs(OUTPUT_DIR, exist_ok=True)
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filepath = os.path.join(OUTPUT_DIR, f"isone_5min_lmp_{timestamp}.csv")
    df.to_csv(filepath, index=False)

    isone_range = append_to_master(df, ISONE_MASTER)
    was_duplicate = isone_range[3]

    # If duplicate, delete the snapshot we just saved (it's identical to what's already in master, so keeping it would just waste disk space).
    # Safe to do because the master file is written and closed before this runs.
    if was_duplicate:
        os.remove(filepath)
        print(f"  (Duplicate interval — snapshot deleted, master unchanged)")
    else:
        print(f"✓ Saved {len(df)} rows → {filepath}")

    return filepath, df, isone_range, was_duplicate


def download_nyiso_lmp():
    """Fetch latest NYISO RT 5-Min LMPs, save snapshot, append to master."""
    nyiso = gridstatus.NYISO()

    print()
    print("----------- NY ISO ----------")
    print("Fetching latest NYISO Real-Time 5-Minute LMPs...")
    df = nyiso.get_lmp(date="latest", market="REAL_TIME_5_MIN", locations="ALL")

    if df is None or df.empty:
        raise ValueError("No NYISO data returned. The market may not be active right now.")

    os.makedirs(OUTPUT_DIR, exist_ok=True)
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filepath = os.path.join(OUTPUT_DIR, f"nyiso_5min_lmp_{timestamp}.csv")
    df.to_csv(filepath, index=False)

    nyiso_range = append_to_master(df, NYISO_MASTER)
    was_duplicate = nyiso_range[3]

    if was_duplicate:
        os.remove(filepath)
        print(f"  (Duplicate interval — snapshot deleted, master unchanged)")
    else:
        print(f"✓ Saved {len(df)} rows → {filepath}")

    return filepath, df, nyiso_range, was_duplicate


# ── Previews ──────────────────────────────────────────────────────────────────

def preview(df, label: str, rows: int = 10, max_cols: int = None):
    """Unified preview for any ISO dataframe. Optionally cap columns."""
    display_df = df.iloc[:, :max_cols] if max_cols else df
    actual_rows = min(rows, len(df))
    col_count = len(display_df.columns)
    total_cols = len(df.columns)
    col_note = f", first {col_count} of {total_cols} columns" if max_cols else f", {total_cols} columns"
    print(f"\n── {label} Preview (first {actual_rows} of {len(df)} rows{col_note}) ──")
    print(display_df.head(rows).to_string(index=False))


# ── Screen control ───────────────────────────────────────────────────────────

def clear_screen():
    """
    Clear output in a way that works in both Google Colab and normal terminals.
    - Colab: uses IPython.display.clear_output (clears the cell output area)
    - Terminal (VS Code, PyCharm, standard shell): uses ANSI escape codes
    """
    try:
        from IPython.display import clear_output
        clear_output(wait=True)   # wait=True holds old output until new is ready
    except ImportError:
        # Not in IPython/Colab — use ANSI escape for regular terminals
        print("\033[2J\033[H", end="", flush=True)


# ── Summary printer ───────────────────────────────────────────────────────────

def print_summary(isone_range, nyiso_range,
                  isone_dup, nyiso_dup,
                  recent_isone, recent_nyiso,
                  last_run_time, run_count):

    fmt = "%B %d, %Y %I:%M:%S %p %Z"

    print()
    print("=" * 60)
    print("             MASTER DOCUMENTS SUMMARY")
    print(f"         (screen refreshed each cycle — run #{run_count})")
    print("=" * 60)

    # ── Recent files ──
    print("\n── Recent ISO-NE files downloaded ──")
    if recent_isone:
        for f in recent_isone:
            print(f"  {f}")
    else:
        print("  (none yet)")

    print("\n── Recent NYISO files downloaded ──")
    if recent_nyiso:
        for f in recent_nyiso:
            print(f"  {f}")
    else:
        print("  (none yet)")

    # ── Master doc ranges ──
    print()
    print("NE ISO MASTER DOC")
    if isone_range and isone_range[0] is not None:
        start, end, count, _ = isone_range
        print(f"  Spans:     {start.strftime(fmt)} → {end.strftime(fmt)}")
        print(f"  Rows:      {count} total rows")
        print(f"  Intervals: {count_intervals(ISONE_MASTER)} unique 5-minute snapshots")

    print()
    print("NY ISO MASTER DOC")
    if nyiso_range and nyiso_range[0] is not None:
        start, end, count, _ = nyiso_range
        print(f"  Spans:     {start.strftime(fmt)} → {end.strftime(fmt)}")
        print(f"  Rows:      {count} total rows")
        print(f"  Intervals: {count_intervals(NYISO_MASTER)} unique 5-minute snapshots")

    # ── Last run time ──
    print()
    print(f"Last execution: {last_run_time.strftime(fmt)}")

    # ── Duplicate / success notification (ALL CAPS, always last) ──
    print()
    if isone_dup and nyiso_dup:
        print("DUPLICATE DETECTED FOR BOTH ISO-NE AND NYISO — NO NEW DATA WAS ADDED TO EITHER MASTER FILE.")
    elif isone_dup:
        print("DUPLICATE DETECTED FOR ISO-NE — NO NEW DATA WAS ADDED TO THE ISO-NE MASTER FILE.")
        print("NYISO UPDATE SUCCESSFUL — NEW DATA HAS BEEN ADDED TO THE NYISO MASTER FILE.")
    elif nyiso_dup:
        print("DUPLICATE DETECTED FOR NYISO — NO NEW DATA WAS ADDED TO THE NYISO MASTER FILE.")
        print("ISO-NE UPDATE SUCCESSFUL — NEW DATA HAS BEEN ADDED TO THE ISO-NE MASTER FILE.")
    else:
        print("UPDATE SUCCESSFUL — NEW DATA HAS BEEN ADDED TO BOTH MASTER FILES.")

    print("=" * 60)


# ── Main loop ─────────────────────────────────────────────────────────────────

if __name__ == "__main__":

    recent_isone = deque(maxlen=RECENT_FILES_N)   # keeps last N file paths
    recent_nyiso = deque(maxlen=RECENT_FILES_N)

    isone_range = nyiso_range = None
    isone_dup = nyiso_dup = False
    run_count = 0

    while True:
        run_count += 1
        last_run_time = datetime.now()

        # Clear screen at the start of every cycle so output replaces itself
        clear_screen()
        print(f"Scheduler running — cycle #{run_count} — fetching every {POLL_INTERVAL // 60} min.")
        print("Press Ctrl+C to stop.\n")

        # ── ISO-NE ──
        try:
            filepath, df, isone_range, isone_dup = download_lmp()
            preview(df, label="ISO-NE")
            if not isone_dup:
                recent_isone.append(filepath)
        except Exception as e:
            print(f"ISO-NE Error: {e}")
            isone_dup = False

        # ── NYISO ──
        try:
            nyiso_filepath, nyiso_df, nyiso_range, nyiso_dup = download_nyiso_lmp()
            preview(nyiso_df, label="NYISO", max_cols=10)
            if not nyiso_dup:
                recent_nyiso.append(nyiso_filepath)
        except Exception as e:
            print(f"NYISO Error: {e}")
            nyiso_dup = False

        # ── Summary (always last) ──
        print_summary(
            isone_range, nyiso_range,
            isone_dup, nyiso_dup,
            list(recent_isone), list(recent_nyiso),
            last_run_time, run_count,
        )

        print(f"\nSleeping {POLL_INTERVAL // 60} minutes until next fetch...\n")
        time.sleep(POLL_INTERVAL)
# Out:
# Scheduler running — cycle #2 — fetching every 2 min.
# Press Ctrl+C to stop.
#
# ----------- NE ISO ----------
# Fetching latest ISO-NE Preliminary Real-Time 5-Minute LMPs...
# ✓ Saved 1209 rows → downloads_ISO/isone_5min_lmp_20260708_102636.csv
#
# ── ISO-NE Preview (first 10 of 1209 rows, 10 columns) ──
#                      Time            Interval Start              Interval End          Market            Location Location Type   LMP  Energy  Congestion  Loss
# 2026-07-08 10:25:00-04:00 2026-07-08 10:25:00-04:00 2026-07-08 10:30:00-04:00 REAL_TIME_5_MIN UN.FRNKLNSQ13.810CC  NETWORK NODE 36.36   36.19         0.0  0.17
# 2026-07-08 10:25:00-04:00 2026-07-08 10:25:00-04:00 2026-07-08 10:30:00-04:00 REAL_TIME_5_MIN UN.FRNKLNSQ13.811CC  NETWORK NODE 36.36   36.19         0.0  0.17
# 2026-07-08 10:25:00-04:00 2026-07-08 10:25:00-04:00 2026-07-08 10:30:00-04:00 REAL_TIME_5_MIN  UN.FRNKLNSQ13.89CC  NETWORK NODE 36.36   36.19         0.0  0.17
# 2026-07-08 10:25:00-04:00 2026-07-08 10:25:00-04:00 2026-07-08 10:30:00-04:00 REAL_TIME_5_MIN UN.ALTRESCO13.8ALTR  NETWORK NODE 35.62   36.19         0.0 -0.57
# 2026-07-08 10:25:00-04:00 2026-07-08 10:25:00-04:00 2026-07-08 10:30:00-04:00 REAL_TIME_5_MIN UN.EDDY    34.5AMOS  NETWORK NODE 36.30   36.19         0.0  0.11
# 2026-07-08 10:25:00-04:00 2026-07-08 10:25:00-04:00 2026-07-08 10:30:00-04:00 REAL_TIME_5_MIN UN.GULFISLD34.5GULF  NETWORK NODE 34.28   36.19         0.0 -1.91
# 2026-07-08 10:25:00-04:00 2026-07-08 10:25:00-04:00 2026-07-08 10:30:00-04:00 REAL_TIME_5_MIN UN.ASCUTNEY46  ASCU  NETWORK NODE 36.41   36.19         0.0  0.22
# 2026-07-08 10:25:00-04:00 2026-07-08 10:25:00-04:00 2026-07-08 10:30:00-04:00 REAL_TIME_5_MIN UN.PEMIGWAS34.5AYER  NETWORK NODE 36.40   36.19         0.0  0.21
# 2026-07-08 10:25:00-04:00 2026-07-08 10:25:00-04:00 2026-07-08 10:30:00-04:00 REAL_TIME_5_MIN UN.ROXBURY 34.5AZIS  NETWORK NODE 32.83   36.19         0.0 -3.36
# 2026-07-08 10:25:00-04:00 2026-07-08 10:25:00-04:00 2026-07-08 10:30:00-04:00 REAL_TIME_5_MIN UN.BELLWSFL6.9 BELL  NETWORK NODE 36.12   36.19         0.0 -0.07
#
# ----------- NY ISO ----------
# Fetching latest NYISO Real-Time 5-Minute LMPs...
#   (Duplicate interval — snapshot deleted, master unchanged)
#
# ── NYISO Preview (first 10 of 15 rows, first 10 of 10 columns) ──
#                      Time            Interval Start              Interval End          Market Location Location Type   LMP  Energy  Congestion  Loss
# 2026-07-08 10:20:00-04:00 2026-07-08 10:20:00-04:00 2026-07-08 10:25:00-04:00 REAL_TIME_5_MIN   CAPITL          Zone 36.45   36.02        -0.0  0.43
# 2026-07-08 10:20:00-04:00 2026-07-08 10:20:00-04:00 2026-07-08 10:25:00-04:00 REAL_TIME_5_MIN   CENTRL          Zone 36.13   36.02        -0.0  0.11
# 2026-07-08 10:20:00-04:00 2026-07-08 10:20:00-04:00 2026-07-08 10:25:00-04:00 REAL_TIME_5_MIN   DUNWOD          Zone 38.25   36.02        -0.0  2.23
# 2026-07-08 10:20:00-04:00 2026-07-08 10:20:00-04:00 2026-07-08 10:25:00-04:00 REAL_TIME_5_MIN   GENESE          Zone 36.42   36.02        -0.0  0.40
# 2026-07-08 10:20:00-04:00 2026-07-08 10:20:00-04:00 2026-07-08 10:25:00-04:00 REAL_TIME_5_MIN      H Q          Zone 35.98   36.02        -0.0 -0.04
# 2026-07-08 10:20:00-04:00 2026-07-08 10:20:00-04:00 2026-07-08 10:25:00-04:00 REAL_TIME_5_MIN   HUD VL          Zone 37.82   36.02        -0.0  1.80
# 2026-07-08 10:20:00-04:00 2026-07-08 10:20:00-04:00 2026-07-08 10:25:00-04:00 REAL_TIME_5_MIN   LONGIL          Zone 38.40   36.02        -0.0  2.38
# 2026-07-08 10:20:00-04:00 2026-07-08 10:20:00-04:00 2026-07-08 10:25:00-04:00 REAL_TIME_5_MIN   MHK VL          Zone 36.81   36.02        -0.0  0.79
# 2026-07-08 10:20:00-04:00 2026-07-08 10:20:00-04:00 2026-07-08 10:25:00-04:00 REAL_TIME_5_MIN   MILLWD          Zone 38.00   36.02        -0.0  1.98
# 2026-07-08 10:20:00-04:00 2026-07-08 10:20:00-04:00 2026-07-08 10:25:00-04:00 REAL_TIME_5_MIN   N.Y.C.          Zone 38.43   36.02        -0.0  2.41
#
# ============================================================
#              MASTER DOCUMENTS SUMMARY
#          (screen refreshed each cycle — run #2)
# ============================================================
#
# ── Recent ISO-NE files downloaded ──
#   downloads_ISO/isone_5min_lmp_20260708_102434.csv
#   downloads_ISO/isone_5min_lmp_20260708_102636.csv
#
# ── Recent NYISO files downloaded ──
#   downloads_ISO/nyiso_5min_lmp_20260708_102434.csv
#
# NE ISO MASTER DOC
#   Spans:     July 08, 2026 02:20:00 PM UTC → July 08, 2026 02:25:00 PM UTC
#   Rows:      2418 total rows
#   Intervals: 2 unique 5-minute snapshots
#
# NY ISO MASTER DOC
#   Spans:     July 08, 2026 02:20:00 PM UTC → July 08, 2026 02:20:00 PM UTC
#   Rows:      15 total rows
#   Intervals: 1 unique 5-minute snapshots
#
# Last execution: July 08, 2026 10:26:34 AM
#
# DUPLICATE DETECTED FOR NYISO — NO NEW DATA WAS ADDED TO THE NYISO MASTER FILE.
# ISO-NE UPDATE SUCCESSFUL — NEW DATA HAS BEEN ADDED TO THE ISO-NE MASTER FILE.
# ============================================================
#
# Sleeping 2 minutes until next fetch...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 304
#     296 print_summary(
#     297     isone_range, nyiso_range,
#     298     isone_dup, nyiso_dup,
#     299     list(recent_isone), list(recent_nyiso),
#     300     last_run_time, run_count,
#     301 )
#     303 print(f"\nSleeping {POLL_INTERVAL // 60} minutes until next fetch...\n")
# --> 304 time.sleep(POLL_INTERVAL)
#
# KeyboardInterrupt:
